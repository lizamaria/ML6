# %%
# import the library
import PyPDF2 as pdf
import re

# %%
# open the file
file = open('1799516.pdf', 'rb')

# %%
# Call the file
file
# Out:
# <_io.BufferedReader name='1799516.pdf'>

# %%
# Create the pdf file reader
pdf_reader = pdf.PdfFileReader(file)

# %%
pdf_reader

# %%
# Get the info
help(pdf_reader)
# Out:
# Help on PdfFileReader in module PyPDF2.pdf object:
#
# class PdfFileReader(builtins.object)
#  |  PdfFileReader(stream, strict=True, warndest=None, overwriteWarnings=True)
#  |
#  |  Initializes a PdfFileReader object.  This operation can take some time, as
#  |  the PDF stream's cross-reference tables are read into memory.
#  |
#  |  :param stream: A File object or an object that supports the standard read
#  |      and seek methods similar to a File object. Could also be a
#  |      string representing a path to a PDF file.
#  |  :param bool strict: Determines whether user should be warned of all
#  |      problems and also causes some correctable problems to be fatal.
#  |      Defaults to ``True``.
#  |  :param warndest: Destination for logging warnings (defaults to
#  |      ``sys.stderr``).
#  |  :param bool overwriteWarnings: Determines whether to override Python's
#  |      ``warnings.py`` module with a custom implementation (defaults to
#  |      ``True``).
#  |
# ...

# %%
# check if the pdf is not encrypted
pdf_reader.getIsEncrypted()
# Out:
# False

# %%
# check the numbers of pages of the doc
pdf_reader.getNumPages()
# Out:
# 10

# %%
# Extract the information of page number one
page1 = pdf_reader.getPage(0)

# %%
# call but in binary form
page1
# Out:
# {'/Type': '/Page',
#  '/MediaBox': [0, 0, 612, 792],
#  '/Parent': {'/Type': '/Pages',
#   '/Kids': [IndirectObject(71, 0),
#    IndirectObject(1, 0),
#    IndirectObject(5, 0),
#    IndirectObject(9, 0),
#    IndirectObject(13, 0),
#    IndirectObject(17, 0),
#    IndirectObject(23, 0),
#    IndirectObject(27, 0),
#    IndirectObject(31, 0),
#    IndirectObject(35, 0)],
#   '/Count': 10},
#  '/Resources': {'/ProcSet': ['/PDF', '/ImageC', '/ImageI', '/Text'],
#   '/ColorSpace': {'/R10': ['/ICCBased', IndirectObject(101, 0)],
#    '/R14': ['/Indexed',
#     IndirectObject(82, 0),
#     15,
#     b'\xff\xff\xff\xff\xdd\xdd\xff\xbb\xbb\xffff\xffDD\xff\xaa\xaa\xff\x00\x00\xff33\xff\xcc\xcc\xff\x99\x99\xff""\xff\xee\xee\xff\x88\x88\xffUU\xff\x11\x11\xffww']},
#   '/ExtGState': {'/R9': {'/Type': '/ExtGState', '/OPM': 1}},
#   '/XObject': {'/R15': {'/Subtype': '/Image',
#     '/ColorSpace': ['/Indexed',
#      IndirectObject(82, 0),
#      15,
# ...

# %%
# call the extracted data
page1.extractText()
# Out:
# 'Material Safety Data Sheet \nRevision Number:\n 004.0\nIssue date:\n 02/01/2012\nIDH number: 701990\nProduct name: DB EPOXY Pot CMPD E-60NC 50ML\nPage 1 of 5 \n1.  PRODUCT AND COMPANY IDENTIFICATION \nProduct name: DB EPOXY Pot CMPD E-60NC 50ML IDH num\nber:\n701990\nProduct type:\nEpoxy Hardener  \nItem number:\n29324_209537\nRegion: \nUnited States\nCompany address: \nContact information: \nHenkel Corporation \n\nOne Henkel Way \n\nRocky Hill, Connecticut 06067\nTelephone: 860.571.5100 \n\nMEDICAL EMERGENCY Phone: Poison Control Center \n\n1-877-671-4608 (toll free) or 1-303-592-1711 \n\nTRANSPORT EMERGENCY Phone: CHEMTREC \n\n1-800-424-9300 (toll free) or 1-703-527-3887 \n\nInternet: www.henkelna.com\n2.  HAZARDS IDENTIFICATION \n EMERGENCY OVERVIEW\n  \nHMIS:\nPhysical state: \nLiquid \nHEALTH: \n *3\nColor: \nPale yellow\nFLAMMABILITY: \n 1\nOdor: \nMild\nPHYSICAL HAZARD: \n0Personal Protection: \n See MSDS Section 8\nDANGER\n:CAUSES EYE, SKIN AND RESPIRATORY TRACT BURNS. \n\nM
# ...

# %%
rex = re.compile("(?<=\%\%(S\))(.*)".re.DOTALL)

# %%
page2 = pdf_reader.getPage(1)

# %% [markdown]
# ### page2.extractText()

# %% [markdown]
# ### Append Write or Merge PDFs

# %%
#pdf_writer = pdf.PdfFileWriter()

# %%
# create a new page
#pdf_writer.addPage(page1)
#Merge pages toghether in one and two
#pdf_writer.addPage(page2)

# %%
#output = open('Pages.pdf', 'wb')
#pdf_writer.write(output)
#output.close()

# %%
text = page2.extractText()

# %%
print(text)
# Out:
# IDH number: 701990
# Product name: DB EPOXY Pot CMPD E-60NC 50ML
# Page 2 of 5
# 4.  FIRST AID MEASURES
# Inhalation:
# Move to fresh air. If not breathing, give artificia
# l respiration. If breathing is
# difficult, give oxygen. Get medical attention.
# Skin contact:
# Immediately flush skin with plenty of water (using
# soap, if available). Remove
# contaminated clothing and footwear. Get medical att
# ention. Wash clothing
# before reuse. Thoroughly clean shoes before reuse.
# Eye contact:
# Immediately flush eyes with water for at least 15 m
# inutes, while holding
# eyelids open.  Seek medical attention at once.
# Ingestion:
# DO NOT induce vomiting unless directed to do so by
# medical personnel.
# Never give anything by mouth to an unconscious pers
# on. Get immediate
# medical attention.
# 5.  FIRE FIGHTING MEASURES
# Flash point:
# > 93 °C (> 199.4 °F)Setaflash Closed Cup
# Autoignition temperature:
# Not available.
# Flammable/Explosive limits - lower:
# Not available.
# ...
